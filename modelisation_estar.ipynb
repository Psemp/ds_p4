# %%
import pandas as pd
import seaborn as sns
import numpy as np
import os

from matplotlib import pyplot as plt
from dotenv import load_dotenv

from scripts.models.regressions import Regressions

load_dotenv()
sns.color_palette('colorblind')
plt.style.use('Solarize_Light2')

# Setting default DPI, pulling it from dotenv if it exists, setting it on 100 if not

try:
    pc_dpi = int(os.getenv('DI'))

except TypeError:
    pc_dpi = 100

if pc_dpi is None:
    pc_dpi = 100

if pc_dpi >= 155:
    pc_dpi = 155

# %%
file_estar = "./data/seattle_scaled_clean_data.csv"

# %%
df_estar = pd.read_csv(file_estar)

# %%
df_estar.head()
# Out:
#    OSEBuildingID  ...  ohe_ptype_Worship Facility
# 0              1  ...                         0.0
# 1              2  ...                         0.0
# 2              5  ...                         0.0
# 3             10  ...                         0.0
# 4             17  ...                         0.0
#
# [5 rows x 31 columns]

# %%
df_estar.set_index("OSEBuildingID", inplace=True)

# %%
df_estar.columns
# Out:
# Index(['scaled_Energy_consumption_(PC1)', 'scaled_Pollution_generated_(PC2)',
#        'ENERGYSTARScore', 'ohe_nbhood_BALLARD', 'ohe_nbhood_CENTRAL',
#        'ohe_nbhood_DELRIDGE', 'ohe_nbhood_DOWNTOWN', 'ohe_nbhood_EAST',
#        'ohe_nbhood_GREATER DUWAMISH', 'ohe_nbhood_LAKE UNION',
#        'ohe_nbhood_MAGNOLIA / QUEEN ANNE', 'ohe_nbhood_NORTH',
#        'ohe_nbhood_NORTHEAST', 'ohe_nbhood_NORTHWEST', 'ohe_nbhood_SOUTHEAST',
#        'ohe_nbhood_SOUTHWEST', 'ohe_ptype_Hospital', 'ohe_ptype_Hotel',
#        'ohe_ptype_K-12 School', 'ohe_ptype_Large Office',
#        'ohe_ptype_Mixed Use Property', 'ohe_ptype_Office', 'ohe_ptype_Other',
#        'ohe_ptype_Refrigerated Warehouse', 'ohe_ptype_Residence Hall',
#        'ohe_ptype_Small & Medium medical facility',
#        'ohe_ptype_Small & Mid-Sized Office',
#        'ohe_ptype_Supermarket & Grocery store', 'ohe_ptype_Warehouse',
#        'ohe_ptype_Worship Facility'],
#       dtype='object')

# %%
estar_target = "ENERGYSTARScore"
estar_regression = Regressions(dataframe=df_estar, target_col=estar_target)

# %%
estar_regression.display_all_metrics()
# Out:
# Step : Elastic Net
# /Users/psemp/Documents/GitHub/ds_p4/env/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:1571: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Step : Lasso
# Step : Ridge
# Step : standard regression
#
# ###############
#
# Standard :
#  - rss  =  163041.30751550003
#  - r2_score  =  0.1628645551099065
#  - rsme  =  24.993585959998754
#  - mae  =  19.918546940009456
#
# ###############
#
# Ridge :
#  - Ridge best alpha = 27.04959730463137
#  - rss  =  169425.96515748074
#  - r2_score  =  0.13008253626426924
#  - rsme  =  25.47825796548628
#  - mae  =  20.55775425578369
#
# ###############
#
# LASSO :
#  - Best LASSO alpha : 0.34
#  - rss  =  55379431.71213002
#  - r2_score  =  0.1286690445260259
#  - rsme  =  25.498948830649677
#  - mae  =  20.578931570243217
#
# ###############
#
# Elastic Net :
#  - Elastic net best l1 ratio = 0.9600000000000001
#  - Elastic net best alpha = 0.20010656450046824
#  - rss  =  56027821.78284516
#  - r2_score  =  0.13453630611761824
#  - rsme  =  25.412952970873178
#  - mae  =  20.444774623170787
