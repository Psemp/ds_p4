# %%
import os
import json

from dotenv import load_dotenv

load_dotenv()

# Setting default DPI, pulling it from dotenv if it exists, setting it on 100 if not

pc_dpi = os.getenv('DPI')

if pc_dpi is None:
    pc_dpi = 100

# %%
metadata_json_fifteen = "data/socrata_metadata_2015-building-energy-benchmarking.json"
metadata_json_sixteen = "data/socrata_metadata_2016-building-energy-benchmarking.json"

# %%
with open(metadata_json_fifteen) as json_file:
    json_fifteen = json.load(json_file)

with open(metadata_json_sixteen) as json_file:
    json_sixteen = json.load(json_file)

# %%
json_fifteen
# Out:
# {'id': 'h7rm-fz6m',
#  'name': '2015 Building Energy Benchmarking',
#  'assetType': 'dataset',
#  'attribution': 'City of Seattle',
#  'attributionLink': 'http://www.seattle.gov/environment',
#  'averageRating': 0,
#  'createdAt': 1492461362,
# ...

# %%
json_sixteen
# Out:
# {'id': '2bpz-gwpy',
#  'name': '2016 Building Energy Benchmarking',
#  'assetType': 'dataset',
#  'attribution': 'City of Seattle',
#  'attributionLink': 'https://www.seattle.gov/energybenchmarking',
#  'averageRating': 0,
#  'createdAt': 1521070051,
# ...
